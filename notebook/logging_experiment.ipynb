# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), "logs")

# %%
os.makedirs("logs", exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%d-%m-%Y_%H-%M-%S')}.log"

# %%
LOG_FILE
# Out:
# '15-07-2026_23-37-21.log'

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    level=logging.INFO,
    format="[%(asctime)s] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
)

# %%
logging.getLogger("DocumentPortal").info("This is an info message.")

# %%
import structlog
log = structlog.get_logger()

# %%
log.info("This is a structlog info message",user_id=123, action="login",file="logging_experiment.ipynb", line=20)
# Out:
# 2026-07-15 23:37:22 [info     ] This is a structlog info message action=login file=logging_experiment.ipynb line=20 user_id=123
